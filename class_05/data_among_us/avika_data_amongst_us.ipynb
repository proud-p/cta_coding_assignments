# %% [markdown]
# # Data Among Us
#
# In this investigation, I aim to explore the hypothesis that the brains of "creatives" and "logicians" function differently in specific ways. Common stereotypes suggest that creatives are better at distinguishing colors, recognizing faces, and perceiving things more holistically, with a focus on creative elements like colors. On the other hand, logicians are thought to approach problems step-by-step, yet they can also perceive systems as a whole, making them more adept at solving riddles.
#
# Additionally, certain studies have shown that color preferences can be linked to emotional and cognitive patterns, so I wanted to see if 'artists' and 'logicians' different cognitive patterns will manifest as different colour preferences.
#
# I do realise creative technologists are probably the worst group of people to be testing this on. Oh Well.
#
# Some research references:
# https://psychology.cornell.edu/news/color-preference-impacts-perception  - how colour preferences impacts perception
# https://pmc.ncbi.nlm.nih.gov/articles/PMC4383146/ - colour psychology
#
# *Hypotheses:*
# - Creatives are better at recognising faces
# - Creatives are better at distinguishing colours
# - logicians are better at logic and riddles

# %% [markdown]
# # Imports

# %%
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/proud_questions.csv')
df.head()
# Out:
#                      Timestamp What did you like learning the most so far?  \
# 0  2024/10/17 4:46:25 PM GMT+1                             Future Machines
# 1  2024/10/17 4:52:14 PM GMT+1                                      Python
# 2  2024/10/17 4:52:44 PM GMT+1                       Unreal - World Making
# 3  2024/10/17 4:53:09 PM GMT+1                       Unreal - World Making
# 4  2024/10/17 4:53:15 PM GMT+1                       Unreal - World Making
#
#   In the picture above, are the 2 dots different colours?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Which country did you grow up in? Which environment did you grow up in?  \
# 0                                UK                           Countryside
# 1                             China                                Suburb
# 2                                uk                                Suburb
# 3                             China                                Suburb
# 4                           England                           Countryside
#
#   What's your favourite colour  \
# 0                        Black
# 1                         Blue
# 2                        Green
# 3                       purple
# 4                     hot pink
#
#    Rate how much the picture above looks like a face - Building  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Rate how much the picture above looks like a face -dots  \
# 0                                                  3
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    How much does the picture above looks like a face? - cloud  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How much does the picture above looks like a face? - (leaf)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#   It is greater than God and more evil than the devil. The poor have it, the rich need it, and if u eat it, you'll die. What is it?  \
# 0                                 Absolutely Nothing
# 1                                               Air?
# 2                                                idk
# 3                                              what?
# 4                                               love
#
#    Go to the store and get a loaf of bread. If they have eggs, get a dozen.  What do you come back with?  \
# 0                                            12 eggs
# 1                                            12 eggs
# 2                                            bananas
# 3                                            bananas
# 4                                             0 eggs
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# # Data Exploration

# %%
print(f"Dataframe has {df.shape[1]} columns, {df.shape[0]} rows")
print(df.columns)
# Out:
# Dataframe has 13 columns, 17 rows
# Index(['Timestamp', 'What did you like learning the most so far?',
#        'In the picture above, are the 2 dots different colours?',
#        'Which country did you grow up in?',
#        'Which environment did you grow up in?', 'What's your favourite colour',
#        'Rate how much the picture above looks like a face - Building',
#        'Rate how much the picture above looks like a face -dots',
#        'How much does the picture above looks like a face? - cloud',
#        'How much does the picture above looks like a face? - (leaf)',
#        'It is greater than God and more evil than the devil. The poor have it, the rich need it, and if u eat it, you'll die. What is it?',
#        ' Go to the store and get a loaf of bread. If they have eggs, get a dozen.  What do you come back with?',
#        'Unnamed: 12'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning / Wrangling

# %%
df.drop(columns=['Timestamp','Unnamed: 12'], inplace=True)
df.head()
# Out:
#   What did you like learning the most so far?  \
# 0                             Future Machines
# 1                                      Python
# 2                       Unreal - World Making
# 3                       Unreal - World Making
# 4                       Unreal - World Making
#
#   In the picture above, are the 2 dots different colours?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Which country did you grow up in? Which environment did you grow up in?  \
# 0                                UK                           Countryside
# 1                             China                                Suburb
# 2                                uk                                Suburb
# 3                             China                                Suburb
# 4                           England                           Countryside
#
#   What's your favourite colour  \
# 0                        Black
# 1                         Blue
# 2                        Green
# 3                       purple
# 4                     hot pink
#
#    Rate how much the picture above looks like a face - Building  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Rate how much the picture above looks like a face -dots  \
# 0                                                  3
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    How much does the picture above looks like a face? - cloud  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How much does the picture above looks like a face? - (leaf)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#   It is greater than God and more evil than the devil. The poor have it, the rich need it, and if u eat it, you'll die. What is it?  \
# 0                                 Absolutely Nothing
# 1                                               Air?
# 2                                                idk
# 3                                              what?
# 4                                               love
#
#    Go to the store and get a loaf of bread. If they have eggs, get a dozen.  What do you come back with?
# 0                                            12 eggs
# 1                                            12 eggs
# 2                                            bananas
# 3                                            bananas
# 4                                             0 eggs

# %%
# renaming columns
column_names = list(df.columns)
new_column_names = ['favourite_learning','different_colours','country_grow','environment_grow','favourite_colour','rate_face_building','rate_face_dots','rate_face_cloud','rate_face_leaf','nothing_riddle_text','eggs_riddle_choice']
rename_cols = dict(zip(column_names,new_column_names))
print(rename_cols)
df.rename(columns=rename_cols , inplace=True)
df.head()
# Out:
# {'What did you like learning the most so far?': 'favourite_learning', 'In the picture above, are the 2 dots different colours?': 'different_colours', 'Which country did you grow up in?': 'country_grow', 'Which environment did you grow up in?': 'environment_grow', "What's your favourite colour": 'favourite_colour', 'Rate how much the picture above looks like a face - Building': 'rate_face_building', 'Rate how much the picture above looks like a face -dots': 'rate_face_dots', 'How much does the picture above looks like a face? - cloud': 'rate_face_cloud', 'How much does the picture above looks like a face? - (leaf)': 'rate_face_leaf', "It is greater than God and more evil than the devil. The poor have it, the rich need it, and if u eat it, you'll die. What is it?": 'nothing_riddle_text', ' Go to the store and get a loaf of bread. If they have eggs, get a dozen.  What do you come back with?': 'eggs_riddle_choice'}
#       favourite_learning different_colours country_grow environment_grow  \
# 0        Future Machines               Yes           UK      Countryside
# 1                 Python               Yes        China           Suburb
# 2  Unreal - World Making               Yes           uk           Suburb
# 3  Unreal - World Making                No        China           Suburb
# 4  Unreal - World Making                No      England      Countryside
#
#   favourite_colour  rate_face_building  rate_face_dots  rate_face_cloud  \
# 0            Black                   5               3                3
# 1             Blue                   5               4                4
# 2            Green                   4               2                1
# 3           purple                   4               3                1
# 4         hot pink                   3               3                1
#
#    rate_face_leaf nothing_riddle_text eggs_riddle_choice
# 0               1  Absolutely Nothing            12 eggs
# 1               1                Air?            12 eggs
# 2               1                 idk            bananas
# 3               1               what?            bananas
# 4               1                love             0 eggs

# %%
# Adding columns converting favourite learning module to scale rank from artistic to logic - Artistic (1) to logic (4)
df['favourite_learning'].value_counts()
rank_list = ['Unreal - World Making','Future Machines','Unreal - Blueprints','Python']
df['rank_art_to_logic'] = df['favourite_learning'].map(lambda x: rank_list.index(x) if x in rank_list else None)
df.head()
# Out:
#       favourite_learning different_colours country_grow environment_grow  \
# 0        Future Machines               Yes           UK      Countryside
# 1                 Python               Yes        China           Suburb
# 2  Unreal - World Making               Yes           uk           Suburb
# 3  Unreal - World Making                No        China           Suburb
# 4  Unreal - World Making                No      England      Countryside
#
#   favourite_colour  rate_face_building  rate_face_dots  rate_face_cloud  \
# 0            Black                   5               3                3
# 1             Blue                   5               4                4
# 2            Green                   4               2                1
# 3           purple                   4               3                1
# 4         hot pink                   3               3                1
#
#    rate_face_leaf nothing_riddle_text eggs_riddle_choice  rank_art_to_logic
# 0               1  Absolutely Nothing            12 eggs                  1
# 1               1                Air?            12 eggs                  3
# 2               1                 idk            bananas                  0
# 3               1               what?            bananas                  0
# 4               1                love             0 eggs                  0

# %%
# Cleaning country column
def clean_country(x):
    y= x.lower()
    if ('england' in y):
        y = 'uk'
    
    return y

# Lowercase everything
df['country_grow_clean'] = df.country_grow.apply(lambda x: clean_country(x))
# change all london / england to uk
df.head()
# Out:
#       favourite_learning different_colours country_grow environment_grow  \
# 0        Future Machines               Yes           UK      Countryside
# 1                 Python               Yes        China           Suburb
# 2  Unreal - World Making               Yes           uk           Suburb
# 3  Unreal - World Making                No        China           Suburb
# 4  Unreal - World Making                No      England      Countryside
#
#   favourite_colour  rate_face_building  rate_face_dots  rate_face_cloud  \
# 0            Black                   5               3                3
# 1             Blue                   5               4                4
# 2            Green                   4               2                1
# 3           purple                   4               3                1
# 4         hot pink                   3               3                1
#
#    rate_face_leaf nothing_riddle_text eggs_riddle_choice  rank_art_to_logic  \
# 0               1  Absolutely Nothing            12 eggs                  1
# 1               1                Air?            12 eggs                  3
# 2               1                 idk            bananas                  0
# 3               1               what?            bananas                  0
# 4               1                love             0 eggs                  0
#
#   country_grow_clean
# 0                 uk
# 1              china
# 2                 uk
# 3              china
# 4                 uk

# %%
# cleaning colour columns - categorising into warm/cold/monochrome/none 

def categorise_colours(colour):
    warm_colours = ['red','yellow','orange','pink','hot pink']
    cold_colours = ['blue','purple','green']
    monochrome = ['black','white']

    if colour in warm_colours:
        return 'warm'
    elif colour in cold_colours:
        return 'cold'
    elif colour in monochrome:
        return 'monochrome'
    else:
        return None

# lower case
df.favourite_colour = df.favourite_colour.apply(lambda x: x.lower().strip())

# assign colour preferences to groups
df['favourite_colour_category_clean'] = df.favourite_colour.apply(lambda x: categorise_colours(x))
df
# Out:
#        favourite_learning different_colours          country_grow  \
# 0         Future Machines               Yes                    UK
# 1                  Python               Yes                 China
# 2   Unreal - World Making               Yes                    uk
# 3   Unreal - World Making                No                 China
# 4   Unreal - World Making                No               England
# 5   Unreal - World Making               Yes                 China
# 6                  Python               Yes                 China
# 7         Future Machines               NaN               Uk & US
# 8     Unreal - Blueprints               Yes                    UK
# 9   Unreal - World Making               Yes                    UK
# 10        Future Machines                No              England
# 11    Unreal - Blueprints                No                 China
# 12        Future Machines                No                China
# 13    Unreal - Blueprints                No               Nigeria
# 14                 Python                No  South London MASSIVE
# 15    Unreal - Blueprints                No               England
# 16  Unreal - World Making               Yes          Myanmar & UK
#
#    environment_grow  favourite_colour  rate_face_building  rate_face_dots  \
# 0       Countryside             black                   5               3
# 1            Suburb              blue                   5               4
# 2            Suburb             green                   4               2
# 3            Suburb            purple                   4               3
# 4       Countryside          hot pink                   3               3
# 5            Suburb             black                   4               5
# 6          Big City              blue                   3               3
# 7          Big City            purple                   5               2
# 8          Big City            orange                   4               3
# 9            Suburb             black                   4               3
# 10      Countryside               red                   4               4
# 11         Big City              blue                   5               5
# 12         Big City              blue                   5               5
# 13         Big City        all colors                   4               3
# 14         Big City            yellow                   5               3
# 15           Suburb  dark light black                   5               5
# 16           Suburb             black                   4               4
#
#     rate_face_cloud  rate_face_leaf nothing_riddle_text eggs_riddle_choice  \
# 0                 3               1  Absolutely Nothing            12 eggs
# 1                 4               1                Air?            12 eggs
# 2                 1               1                 idk            bananas
# 3                 1               1               what?            bananas
# 4                 1               1                love             0 eggs
# 5                 5               2    hmmmm...freedom?            bananas
# 6                 4               2             nothing            bananas
# 7                 3               1              poison           12 bread
# 8                 2               1             nothing            bananas
# 9                 3               1             empathy            bananas
# 10                4               2             Nothing           12 bread
# 11                4               1                 Ego            bananas
# 12                4               2               apple            bananas
# 13                2               1             Nothing            12 eggs
# 14                5               2        A human Soul            bananas
# 15                4               3             Nothing           12 bread
# 16                3               1             Empathy           12 bread
#
#     rank_art_to_logic    country_grow_clean favourite_colour_category_clean
# 0                   1                    uk                      monochrome
# 1                   3                 china                            cold
# 2                   0                    uk                            cold
# 3                   0                 china                            cold
# 4                   0                    uk                            warm
# 5                   0                 china                      monochrome
# 6                   3                 china                            cold
# 7                   1               uk & us                            cold
# 8                   2                    uk                            warm
# 9                   0                    uk                      monochrome
# 10                  1                    uk                            warm
# 11                  2                 china                            cold
# 12                  1                china                             cold
# 13                  2               nigeria                            None
# 14                  3  south london massive                            warm
# 15                  2                    uk                            None
# 16                  0          myanmar & uk                      monochrome

# %%
# Check if they got the nothing riddle correct or not

df.nothing_riddle_text = df.nothing_riddle_text.apply(lambda x:x.lower().strip())
df['nothing_riddle_correct_clean'] = df.nothing_riddle_text.apply(lambda x: 'nothing' in x )
df
# Out:
#        favourite_learning different_colours          country_grow  \
# 0         Future Machines               Yes                    UK
# 1                  Python               Yes                 China
# 2   Unreal - World Making               Yes                    uk
# 3   Unreal - World Making                No                 China
# 4   Unreal - World Making                No               England
# 5   Unreal - World Making               Yes                 China
# 6                  Python               Yes                 China
# 7         Future Machines               NaN               Uk & US
# 8     Unreal - Blueprints               Yes                    UK
# 9   Unreal - World Making               Yes                    UK
# 10        Future Machines                No              England
# 11    Unreal - Blueprints                No                 China
# 12        Future Machines                No                China
# 13    Unreal - Blueprints                No               Nigeria
# 14                 Python                No  South London MASSIVE
# 15    Unreal - Blueprints                No               England
# 16  Unreal - World Making               Yes          Myanmar & UK
#
#    environment_grow  favourite_colour  rate_face_building  rate_face_dots  \
# 0       Countryside             black                   5               3
# 1            Suburb              blue                   5               4
# 2            Suburb             green                   4               2
# 3            Suburb            purple                   4               3
# 4       Countryside          hot pink                   3               3
# 5            Suburb             black                   4               5
# 6          Big City              blue                   3               3
# 7          Big City            purple                   5               2
# 8          Big City            orange                   4               3
# 9            Suburb             black                   4               3
# 10      Countryside               red                   4               4
# 11         Big City              blue                   5               5
# 12         Big City              blue                   5               5
# 13         Big City        all colors                   4               3
# 14         Big City            yellow                   5               3
# 15           Suburb  dark light black                   5               5
# 16           Suburb             black                   4               4
#
#     rate_face_cloud  rate_face_leaf nothing_riddle_text eggs_riddle_choice  \
# 0                 3               1  absolutely nothing            12 eggs
# 1                 4               1                air?            12 eggs
# 2                 1               1                 idk            bananas
# 3                 1               1               what?            bananas
# 4                 1               1                love             0 eggs
# 5                 5               2    hmmmm...freedom?            bananas
# 6                 4               2             nothing            bananas
# 7                 3               1              poison           12 bread
# 8                 2               1             nothing            bananas
# 9                 3               1             empathy            bananas
# 10                4               2             nothing           12 bread
# 11                4               1                 ego            bananas
# 12                4               2               apple            bananas
# 13                2               1             nothing            12 eggs
# 14                5               2        a human soul            bananas
# 15                4               3             nothing           12 bread
# 16                3               1             empathy           12 bread
#
#     rank_art_to_logic    country_grow_clean favourite_colour_category_clean  \
# 0                   1                    uk                      monochrome
# 1                   3                 china                            cold
# 2                   0                    uk                            cold
# 3                   0                 china                            cold
# 4                   0                    uk                            warm
# 5                   0                 china                      monochrome
# 6                   3                 china                            cold
# 7                   1               uk & us                            cold
# 8                   2                    uk                            warm
# 9                   0                    uk                      monochrome
# 10                  1                    uk                            warm
# 11                  2                 china                            cold
# 12                  1                china                             cold
# 13                  2               nigeria                            None
# 14                  3  south london massive                            warm
# 15                  2                    uk                            None
# 16                  0          myanmar & uk                      monochrome
#
#     nothing_riddle_correct_clean
# 0                           True
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# 5                          False
# 6                           True
# 7                          False
# 8                           True
# 9                          False
# 10                          True
# 11                         False
# 12                         False
# 13                          True
# 14                         False
# 15                          True
# 16                         False

# %% [markdown]
# # Data Analytics

# %%
# Correlation between artistic to logic and recognising faces in objects
df_rate_face = df[['rank_art_to_logic','rate_face_leaf','rate_face_dots','rate_face_cloud','rate_face_building']]

df_rate_face.corr()
# Out:
#                     rank_art_to_logic  rate_face_leaf  rate_face_dots  \
# rank_art_to_logic            1.000000        0.295404        0.101801
# rate_face_leaf               0.295404        1.000000        0.531216
# rate_face_dots               0.101801        0.531216        1.000000
# rate_face_cloud              0.476808        0.627375        0.609533
# rate_face_building           0.303646        0.138675        0.303260
#
#                     rate_face_cloud  rate_face_building
# rank_art_to_logic          0.476808            0.303646
# rate_face_leaf             0.627375            0.138675
# rate_face_dots             0.609533            0.303260
# rate_face_cloud            1.000000            0.443456
# rate_face_building         0.443456            1.000000

# %%
# Plot the histogram with KDE, dodge instead of stacking
df_melted = df_rate_face.drop(columns = ['rank_art_to_logic']).melt().rename(columns={'value':'ratings','variable':'rate_face_type'})
sns.histplot(data=df_melted, x='ratings', hue='rate_face_type', stat='count', multiple="dodge", palette="bright")

# Set the x-ticks to be integers
plt.xticks(np.arange(df_melted['ratings'].min(), df_melted['ratings'].max() + 1, 1))
custom_labels = ['Building', 'Dots', 'Cloud', 'Leaf']  # Replace with your desired labels
plt.legend(title="Face Type", labels=custom_labels, loc="upper right", bbox_to_anchor=(1.3, 1))
plt.title('Rating of how much Things looks like a Face')


# Show the plot
plt.show()

# %%
# More 'artistic' people are more likely to recognise other things as faces


face_columns =['rate_face_leaf','rate_face_dots','rate_face_cloud','rate_face_building']
thing_name = ['Leaf','Dots','Cloud','Building']

for i,column in enumerate(face_columns):

    # Create a boxplot for each face rating and learning preference
    plt.figure(figsize=(10, 6))
    sns.violinplot(x='favourite_learning', y=column, data=df,palette='bright',hue='favourite_learning')
    plt.title(f'Face Rating ({thing_name[i]}) by Learning Preference')
    plt.xticks(rotation=45)  # Rotate the x-axis labels for readability
    plt.show()

# %%
# More 'artistic' people are more likely to recognise other things as faces


face_columns =['rate_face_leaf','rate_face_dots','rate_face_cloud','rate_face_building']
thing_name = ['Leaf','Dots','Cloud','Building']

df['sum_faces'] = df[face_columns].sum(axis=1)



# Create a boxplot for each face rating and learning preference
plt.figure(figsize=(10, 6))
sns.violinplot(x='favourite_learning', y='sum_faces', data=df,palette='bright',hue='favourite_learning')
plt.title(f'Summed Face Rating by Learning Preference')
plt.xticks(rotation=45)  # Rotate the x-axis labelrs for readability
plt.show()

# %%
# Split number fo people who can tell colours apart into another df

df_colours_apart = pd.DataFrame(df[['favourite_learning','different_colours']].value_counts().reset_index())
df_colours_apart
# Out:
#       favourite_learning different_colours  count
# 0  Unreal - World Making               Yes      4
# 1    Unreal - Blueprints                No      3
# 2        Future Machines                No      2
# 3                 Python               Yes      2
# 4  Unreal - World Making                No      2
# 5        Future Machines               Yes      1
# 6                 Python                No      1
# 7    Unreal - Blueprints               Yes      1

# %%
#  More 'artistic' people are more likely to be able to tell 2 colours apart
import math

y= df_colours_apart['count']
yint = range(min(y), math.ceil(max(y))+1)
sns.barplot(df_colours_apart,x='favourite_learning',y='count',hue ='different_colours')

plt.xticks(rotation=45)
plt.yticks(yint)
plt.title('Number of People in each Favourite Subject Group who can tell 2 Colours Apart\n')
# Out:
# Text(0.5, 1.0, 'Number of People in each Favourite Subject Group who can tell 2 Colours Apart\n')

# %%
# Pie chart riddle

eggs_riddle_df= df['eggs_riddle_choice'].value_counts().reset_index()
print(eggs_riddle_df)

colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(eggs_riddle_df['count'], labels=eggs_riddle_df['eggs_riddle_choice'], colors = colors, autopct='%.0f%%')
plt.title('Go to the store and get a loaf of bread. If they have eggs, get a dozen.  What do you come back with?')
plt.show()
# Out:
#   eggs_riddle_choice  count
# 0            bananas      9
# 1           12 bread      4
# 2            12 eggs      3
# 3             0 eggs      1

# %%
# Pivot out egg riddle choice for nested bar graph
df_pivot = pd.DataFrame(df[['eggs_riddle_choice','favourite_learning']].value_counts()).reset_index()
df_pivot = df_pivot.pivot(index='eggs_riddle_choice', columns='favourite_learning', values='count')
df_pivot
# Out:
# favourite_learning  Future Machines  Python  Unreal - Blueprints  \
# eggs_riddle_choice
# 0 eggs                          NaN     NaN                  NaN
# 12 bread                        2.0     NaN                  1.0
# 12 eggs                         1.0     1.0                  1.0
# bananas                         1.0     2.0                  2.0
#
# favourite_learning  Unreal - World Making
# eggs_riddle_choice
# 0 eggs                                1.0
# 12 bread                              1.0
# 12 eggs                               NaN
# bananas                               4.0

# %%
# Re-plotting the stacked bar graph
df_pivot.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title('Go to the store and get a loaf of bread. If they have eggs, get a dozen.  What do you come back with?')
plt.xlabel("Eggs Riddle Choice")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Favourite Learning", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# CTA3 Diversity
colors = sns.color_palette('pastel')[0:7]

df_country = pd.DataFrame(df['country_grow_clean'].value_counts()).reset_index()

#create pie chart
plt.pie(df_country['count'], labels=df_country['country_grow_clean'], colors = colors, autopct='%.0f%%')

plt.title('CTA Diversity')
# Out:
# Text(0.5, 1.0, 'CTA Diversity')

# %%
# how bad are people at riddles
# Pivot out table

df_pivot = pd.DataFrame(df[['nothing_riddle_correct_clean','favourite_learning']].value_counts()).reset_index()
df_pivot = df_pivot.pivot(index='nothing_riddle_correct_clean', columns='favourite_learning', values='count')
df_pivot
# Out:
# favourite_learning            Future Machines  Python  Unreal - Blueprints  \
# nothing_riddle_correct_clean
# False                                     2.0     2.0                  1.0
# True                                      2.0     1.0                  3.0
#
# favourite_learning            Unreal - World Making
# nothing_riddle_correct_clean
# False                                           6.0
# True                                            NaN

# %%
#Plot the stacked bar graph for Nothing riddle
df_pivot.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title("Who Solved the Nothing Riddle?")
plt.xlabel("Solved")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Favourite Learning", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
